# %%
# %matplotlib inline

import oscars.sr
from oscars.plots_mpl import *
from oscars.util import *
from oscars.fit import *

import numpy as np
from glob import glob
# Out:
# OSCARS v2.0.2 - Open Source Code for Advanced Radiation Simulation
# Brookhaven National Laboratory, Upton NY, USA
# http://oscars.bnl.gov
# oscars@bnl.gov

# %%
osr = oscars.sr.sr(gpu=1, nthreads=8)
# Out:
# GPU is not available: Setting gpu global setting to 0.

# %%
osr.set_particle_beam(beam='NSLSII', x0=[0, 0, -1])
osr.set_ctstartstop(0, 2)

# %%
# For reading and interpolating a list of files
file_list = read_file_list('/Users/dhidas/OSCARS-dev/NSLSII-MM-Data/SST/U42/file_list.txt')

# %%
gaps = np.arange(11.5, 20, 0.5).tolist() + np.arange(20., 40., 1.).tolist() + np.arange(40., 105., 5.).tolist()
print('ngaps:', len(gaps))
for gap in gaps:
    print('gap', gap)
    osr.clear_bfields()
    osr.add_bfield_interpolated(mapping=file_list,
                                iformat='OSCARS1D Z Bx By Bz',
                                parameter=gap,
                                scale=[0.001],
                                name='U42'
                               )
    osr.calculate_spectrum(obs=[0, 0, 30],
                           energy_range_eV=[10, 10000],
                           ofile='spectra/spectrum_se_u42_gap_' + str(gap).zfill(5) + '.dat',
                          )
# Out:
# ngaps: 3
# gap 12
# gap 14
# gap 17

# %%
files = glob('spectra/spectrum_se_u42_gap_*.dat')

# %%
def find_spacing (spectrum, maxh=8):
    print('hello')
    try:
        fit_1 = fit_spectrum_gaussian(spectrum, n=1, quiet=True)[0][1]
    except ValueError:
        print('failed 1 fit')
        Y = [s[1] for s in spectrum]
        X = [s[0] for s in spectrum]
        ind = Y.index(max(Y))
        return X[ind]

    if maxh == 1:
        print('return fit_1')
        return fit_1
    
    try:
        f2 = fit_spectrum_gaussian(spectrum, n=2, quiet=True)[0][1]
    except ValueError:
        print('return fit_1 failed 2')
        return fit_1

    if maxh == 2:
        return f2


    try:
        last_spacing=0
        for i in range(3, maxh):
            points = [fit[1] for fit in fit_spectrum_gaussian(spectrum, n=i, quiet=True)]

            diffs=[]
            for j in range(1, len(points)):
                diffs.append(points[j] - points[j-1])
                spacing = np.mean(diffs)
                if abs(last_spacing - spacing)/spacing < 0.01:
                    print('found spacing!')
                    return spacing/2
                last_spacing = spacing
    except ValueError:
        print('failed all fit')

    return fit_1


def find_first_harmonic (spectrum, xguess, xwidth=50):
    print('xguess', xguess)
    return fit_spectrum_gaussian(spectrum, xranges=[[xguess-xwidth, xguess+xwidth]], quiet=True)

def find_odd_harmonics (spectrum, first, xwidth=50, figsize=None):
    
        
    xranges=[]
    for x in np.arange(first[0][1], spectrum[-1][0], 2*first[0][1], dtype=float):
        xranges.append([x - xwidth, x + xwidth])
        #fits.append( fit_spectrum_gaussian(spectrum, xranges=[[x - xwidth, x + xwidth]]) )
    print('nxranges', len(xranges))
    fits = fit_spectrum_gaussian(spectrum, xranges=xranges, figsize=figsize)
    return fits

# %%
fits=[]
gaps=[]
for file in files:
    gap = float(file.split('_')[-1][0:5])
    print('gap', gap)
    spectrum = osr.average_spectra(ifiles=[file])
    
    if gap > 78:
        continue
        
    hmax = 8
    if gap > 45.:
        hmax = 1
        
    spacing = find_spacing(spectrum, hmax)
    first = find_first_harmonic(spectrum, spacing)

    fit = find_odd_harmonics(spectrum, first, figsize=[12, 3])
    fits.append(fit)
    gaps.append(gap)
# Out:
# gap 12.0
# hello
# found spacing!
# xguess 334.987861007
# nxranges 15
# gap 14.0
# hello
# found spacing!
# xguess 428.083148475
# nxranges 12
# gap 17.0
# hello
# found spacing!
# xguess 598.963696128
# nxranges 8
# gap 11.5
# hello
# found spacing!
# xguess 314.125926925
# nxranges 16
# gap 12.0
# hello
# found spacing!
# xguess 334.987861009
# nxranges 15
# gap 12.5
# hello
# found spacing!
# xguess 356.802491823
# nxranges 14
# gap 13.0
# hello
# found spacing!
# xguess 379.45596892
# nxranges 13
# gap 13.5
# hello
# found spacing!
# xguess 403.213626345
# nxranges 12
# gap 14.0
# hello
# found spacing!
# xguess 428.083148475
# nxranges 12
# gap 14.5
# hello
# found spacing!
# xguess 453.994394592
# nxranges 11
# gap 15.0
# hello
# found spacing!
# xguess 480.942750586
# nxranges 10
# gap 15.5
# hello
# found spacing!
# xguess 508.868353067
# nxranges 10
# gap 16.0
# hello
# found spacing!
# xguess 537.89037252
# nxranges 9
# gap 16.5
# hello
# found spacing!
# xguess 567.930126028
# nxranges 9
# gap 17.0
# hello
# found spacing!
# xguess 598.963716705
# nxranges 8
# gap 17.5
# hello
# found spacing!
# xguess 630.963637596
# nxranges 8
# gap 18.0
# hello
# found spacing!
# xguess 664.104885017
# nxranges 8
# gap 18.5
# hello
# found spacing!
# xguess 697.975709672
# nxranges 7
# gap 19.0
# hello
# found spacing!
# xguess 732.699246364
# nxranges 7
# gap 19.5
# hello
# found spacing!
# xguess 768.212809787
# nxranges 7
# gap 20.0
# hello
# found spacing!
# xguess 804.449173336
# nxranges 6
# gap 21.0
# hello
# found spacing!
# xguess 878.77435048
# nxranges 6
# gap 22.0
# hello
# found spacing!
# xguess 954.912265062
# nxranges 5
# gap 23.0
# hello
# found spacing!
# xguess 1031.99698062
# nxranges 5
# gap 24.0
# hello
# found spacing!
# xguess 1109.12554554
# nxranges 5
# gap 25.0
# hello
# found spacing!
# xguess 1185.41476025
# nxranges 4
# gap 26.0
# hello
# found spacing!
# xguess 1260.02591934
# nxranges 4
# gap 27.0
# hello
# found spacing!
# xguess 1332.12485129
# nxranges 4
# gap 28.0
# hello
# found spacing!
# xguess 1400.97839712
# nxranges 4
# gap 29.0
# hello
# found spacing!
# xguess 1466.00185425
# nxranges 3
# gap 30.0
# hello
# found spacing!
# xguess 1526.77620194
# nxranges 3
# gap 31.0
# hello
# found spacing!
# xguess 1583.04080508
# nxranges 3
# gap 32.0
# hello
# found spacing!
# xguess 1634.66434672
# nxranges 3
# gap 33.0
# hello
# found spacing!
# xguess 1681.65196598
# nxranges 3
# gap 34.0
# hello
# failed all fit
# xguess 1723.341046
# nxranges 3
# gap 35.0
# hello
# failed all fit
# xguess 1761.5101562
# nxranges 3
# gap 36.0
# hello
# failed all fit
# xguess 1795.66027772
# nxranges 3
# gap 37.0
# hello
# failed all fit
# xguess 1826.04696908
# nxranges 3
# gap 38.0
# hello
# failed all fit
# xguess 1852.94724388
# nxranges 3
# gap 39.0
# hello
# failed all fit
# xguess 1876.65816766
# nxranges 3
# gap 40.0
# hello
# failed all fit
# xguess 1897.49363891
# nxranges 3
# gap 45.0
# hello
# failed all fit
# xguess 1968.06520986
# nxranges 3
# gap 50.0
# hello
# return fit_1
# xguess 2002.73118615
# nxranges 2
# gap 55.0
# hello
# return fit_1
# xguess 2019.79228726
# nxranges 2
# gap 60.0
# hello
# return fit_1
# xguess 2027.60044936
# nxranges 2
# gap 65.0
# hello
# return fit_1
# xguess 2030.7653668
# nxranges 2
# gap 70.0
# hello
# return fit_1
# xguess 2031.89797684
# nxranges 2
# gap 75.0
# hello
# return fit_1
# xguess 2032.33843723
# nxranges 2
# gap 80.0
# gap 85.0
# gap 90.0
# gap 95.0
# gap 100.0

# %%
plt.figure(1, figsize=[12, 8])

#for i in range(len(fits[0])):
for i in range(7):

    X=[]
    Y=[]
    for j in range(len(fits)):
        fit = fits[j]
        if i < len(fit):
            X.append(gaps[j])
            Y.append(fit[i][1])
    plt.plot(Y, X, '.-', label='h'+str(1+2*i))

plt.title('SST U42 - Single Electron (Preliminary)')
plt.xlabel('Photon Energy [eV]')
plt.ylabel('Gap [mm]')

plt.legend(title='Harmonics')

plt.grid()

plt.show()

# %%
plt.figure(1, figsize=[12, 8])

#for i in range(len(fits[0])):
for i in range(7):

    X=[]
    Y=[]
    for j in range(len(fits)):
        fit = fits[j]
        if i < len(fit):
            X.append(fit[i][0])
            Y.append(fit[i][1])
    plt.plot(Y, X, '.-', label=str(1+2*i))
plt.semilogy(1)
#plt.semilogx(1)


plt.ylim([1e13, 6e14])

plt.title('SST U42 - Single Electron 30 [m] on-axis @ 500 [mA] (Preliminary)')
plt.xlabel('Photon Energy [eV]')
plt.ylabel('Flux [$\gamma / mm^2 / 0.1\%bw / s$]')

plt.legend(title='Harmonics')

plt.grid()

plt.show()
